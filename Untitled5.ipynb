# %%
Vertices = ["1", "2", "3", "4", "5", "6", "7"]
G = [[],
     [2, 3],
     [1, 3],
     [4, 6],
     [0, 1, 3],
     [2, 4],
     [4]]

# %%
n = len(G)
for u in range(n):
  for v in G[u]:
    print(f"Hay arco desde el nodo {Vertices[u]} al nodo {Vertices[v]}")
