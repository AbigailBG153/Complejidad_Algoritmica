# %%
G=[[0,0,0,0,0],
   [0,1,1,1,3],
   [0,1,0,1,0],
   [0,1,1,1,3],
   [0,0,0,0,0]]

# %%
import numpy as np

# %%
G = np.array(G)
print(G)
# Out:
# [[0 0 0 0 0]
#  [0 1 1 1 3]
#  [0 1 0 1 0]
#  [0 1 1 1 3]
#  [0 0 0 0 0]]

# %%
import graphviz as gv
