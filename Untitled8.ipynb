# %%
def prim(w,n,s):
  v = []
  while(len(v) != n):
    v.append(0)
  v[s] = 1
  E = []
  for i in range(0,n-1):
    minimo = 9 #no existe
    agregar_vertice = 0
    e = []
    for j in range(0,n):
      if(v[j] == 1):
        for k in range(0,n):
          if(v[k] == 0 and w[j][k] < minimo):
            agregar_vertice = k
            e = [j,k]
            minimo = w[j][k]

    v[agregar_vertice] = 1
    E.append(e)

  return E
